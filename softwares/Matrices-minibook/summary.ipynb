# %% [markdown]
# # End - الخاتمة
#
# شكراً لقراءتك كامل الكتاب
#
# الكتاب مجاني , وتم نشره في قيتهب وأيضاً بإذن الله ستتوفر له نسخة رقمية كملف بي دي إف لكن لا أعلم متى وسيكون بشكل مجاني أيضاً
#
# لاتنسى المتابعة والدعم والتفاعل ونشر الكتاب إن أعجبك وقام بإفادتك

# %% [markdown]
# ### Credits
# [0xSaad](https://x.com/0xdonzdev)

# %% [markdown]
# #### شيء غير مهم في الأسفل قم بتجاهله

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', '--to', 'html', 'summary.ipynb'])
# Out:
# 0
